# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\pratibha\anaconda3.10\lib\site-packages (1.5.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pratibha\anaconda3.10\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\pratibha\anaconda3.10\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pratibha\anaconda3.10\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\pratibha\anaconda3.10\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\pratibha\anaconda3.10\lib\site-packages (1.23.5)Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\pratibha\anaconda3.10\lib\site-packages (0.2.54)
# Requirement already satisfied: pytz>=2022.5 in c:\users\pratibha\anaconda3.10\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: requests>=2.31 in c:\users\pratibha\anaconda3.10\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\pratibha\anaconda3.10\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\pratibha\anaconda3.10\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\pratibha\anaconda3.10\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\pratibha\anaconda3.10\lib\site-packages (from yfinance) (2.5.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\pratibha\anaconda3.10\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\pratibha\anaconda3.10\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\pratibha\anaconda3.10\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pratibha\anaconda3.10\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pratibha\anaconda3.10\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pratibha\anaconda3.10\lib\site-packages (from requests>=2.31->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pratibha\anaconda3.10\lib\site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pratibha\anaconda3.10\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pratibha\anaconda3.10\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: six>=1.5 in c:\users\pratibha\anaconda3.10\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.3.0->yfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %%
stock_symbol = 'AAPL'
data = yf.download(stock_symbol, start = '2020-01-01', end = '2021-12-31')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
# Calculate 50-day Simple Moving Average (SMA)
data['SMA_50'] = data['Close'].rolling(window=50).mean()

# %%
data['SMA_50']
# Out:
# Date
# 2020-01-02           NaN
# 2020-01-03           NaN
# 2020-01-06           NaN
# 2020-01-07           NaN
# 2020-01-08           NaN
#                  ...
# 2021-12-23    156.065309
# 2021-12-27    156.788249
# 2021-12-28    157.469549
# 2021-12-29    158.119056
# 2021-12-30    158.701991
# Name: SMA_50, Length: 504, dtype: float64

# %%
# Calculate 20-day Exponential Moving Average (EMA)
data['EMA_20'] = data['Close'].ewm(span=20, adjust=False).mean()

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Close Price')
plt.plot(data.index, data['SMA_50'], label='50-Day SMA', color='orange')
plt.plot(data.index, data['EMA_20'], label='20-Day EMA', color = 'green')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(f'{stock_symbol} Stock Price with Moving Average')
plt.legend()
plt.show()
